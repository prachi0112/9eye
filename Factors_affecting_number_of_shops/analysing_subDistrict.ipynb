# %%
import pandas as pd

# %%
df = pd.read_excel("Delhinew_vinay.xlsx")

# %%
df.head()
# Out:
#                 STORE NAME Executive Name          AREA       PHONE 1 PHONE 2  \
# 0        Akas Optical Shop          sahil  ADARSH NAGAR  098129 98911     NaN
# 1          Alisha Opticals          sahil  ADARSH NAGAR           NaN     NaN
# 2              Aman optics            NaN  ADARSH NAGAR    9891110907     NaN
# 3  Dr. K.L. Sethi eye care            NaN  ADARSH NAGAR    9988656453     NaN
# 4          Eye care centre          Naman  ADARSH NAGAR    9999666002     NaN
#
#                                              ADDRESS      CONTACT  \
# 0      B-970, Block H 3, Jahangirpuri, Delhi, 110033  98129 98911
# 1  D-483, Railway Rd, Sadi Nagar, Azadpur, Ashok ...          NaN
# 2  A-13, GT Karnal road, Adarsh Nagar, New Delhi-...   9891110907
# 3   C-5, aryasamaj road, Adarsh Nagar new Delhi-1...   9988656453
# 4  C-5 ,Shop no.-3 Arya samaj road, Adarsh Nagar,...   9999666002
#
#    MOBILE NUMBERS                                      WHATSAPP LINK  \
# ...

# %%
pd.value_counts(df['subDistrict'])
# Out:
# Saraswati Vihar      135
# Patel Nagar          121
# Hauz Khas            112
# Kotwali              111
# Punjabi Bagh          94
# Kalkaji               84
# Najafgarh             76
# Vivek Vihar           71
# Rajouri Garden        67
# Preet Vihar           61
# Model Town            54
# Narela                42
# Seelam Pur            41
# Defence Colony        41
# Karol Bagh            36
# Civil Lines           24
# Vasant Vihar          21
# Shahdara              19
# Sadar Bazar           13
# Connaught Place       12
# Gandhi Nagar          11
# Gurgaon                8
# Chanakya Puri          6
# Pahar Ganj             5
# Darya Ganj             3
# Parliament Street      2
# Delhi Cantonment       1
# Seema Puri             1
# Name: subDistrict, dtype: int64

# %%
pd.value_counts(df['AREA'])
# Out:
# BALLIMARAN                 82
# Patparganj                 43
# Rithala                    35
# PASCHIM VIHAR              34
# Uttam Nagar                31
#                            ..
# Matia mahal                 2
# GHONDA                      2
# Rohtash Nagar, Shahdara     1
# chandni chowk               1
# kondli                      1
# Name: AREA, Length: 66, dtype: int64

# %%
saraswati_vihar = df[df['subDistrict'] == "Saraswati Vihar"]

# %%
pd.value_counts(saraswati_vihar['AREA'])
# Out:
# Rithala          30
# SHALIMAR BAGH    23
# Shakur basti     21
# WAZIRPUR         18
# TRINAGAR         17
# Sultanpuri       14
# MANGOLPURI       11
# Punjabi Bagh      1
# Name: AREA, dtype: int64

# %%
chandni = df[df['AREA'] == 'chandni chowk']

# %%
chandni
# Out:
#          STORE NAME Executive Name           AREA     PHONE 1 PHONE 2  \
# 217  Ankit Opticals           Puru  chandni chowk  9899120572     NaN
#
#                                                ADDRESS     CONTACT  \
# 217  106, Near Mandir,, Gali Kandle Kashan, Fatehpu...  9899120572
#
#      MOBILE NUMBERS                                      WHATSAPP LINK  \
# 217    9.899121e+09  https://api.whatsapp.com/send?phone=+919899120572
#
#                                           CALL SUMMARY  ...  Unnamed: 13  \
# 217  He will also talk to his elder brother and the...  ...          NaN
#
#     Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17  Unnamed: 18      long  \
# 217         NaN          NaN          NaN         NaN          NaN  77.22197
#
#            lat subDistrict                                           ADDRESS2
# 217  28.656641     Kotwali  106, Near Mandir,, Gali Kandle Kashan, Fatehpu...
#
# [1 rows x 23 columns]

# %%
paschim = df[df['AREA'] == 'PASCHIM VIHAR']
paschim
# Out:
#                                            STORE NAME Executive Name  \
# 719                                    Chandan Optics            NaN
# 720                                MANCHANDA OPTICALS            NaN
# 721                                   Bhatia opticals            NaN
# 722                                     Tosh Opticals            NaN
# 723                                      Eye Optician            NaN
# 724                                Accurate Opticians            NaN
# 725                                    York Opticians            NaN
# 726                                 Ten Down Opticals            NaN
# 727                                 Shashwat Opticals            NaN
# 728                                      Optical City            NaN
# 729                                Broadways Opticals            NaN
# 730                                    Nazar Opticals            NaN
# 731                                    Capil Opticals            NaN
# ...

# %%
patel_nagar = df[df['subDistrict'] == "Patel Nagar"]
pd.value_counts(patel_nagar['AREA'])
# Out:
# Uttam Nagar       30
# MOTI NAGAR        24
# VIKASPURI         19
# Rajouri garden    15
# Tilak Nagar        7
# Punjabi Bagh       7
# PUNJABI BAGH       5
# JANAKPURI          4
# NAJAFGARH          4
# SHAHDRA            1
# Rajendar nagar     1
# BADARPUR           1
# TRINAGAR           1
# Shakur basti       1
# New delhi          1
# Name: AREA, dtype: int64
